# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from useful_func import *

# %%
df = pd.read_csv("customer_segmentation_uncleaned_data.csv")
df.head()
# Out:
#    CustomerID   Age  Annual_Income_k$  Spending_Score  Purchase_Frequency  \
# 0           1  56.0             65.03              23                   3
# 1           2  69.0            103.57              40                   3
# 2           3  46.0             47.20              82                   7
# 3           4  32.0             44.72              46                   8
# 4           5  60.0             57.67              67                   2
#
#    Gender
# 0  Female
# 1    Male
# 2  Female
# 3  Female
# 4  Female

# %%
#  missing values find

# %%
missing_info(df)
# Out:
# Empty DataFrame
# Columns: [col_name, num_missing_values, per_missing_values]
# Index: []

# %%
# find and visulizaing outliers

# %%
out_info(df)
# Out:
#              col_name   method  num_outliers  %_outliers          uw  \
# 0    Annual_Income_k$      IQR          1465        1.46  123.945000
# 1  Purchase_Frequency  Z_Score           557        0.56   11.719454
# 2      Spending_Score      IQR           500        0.50  151.000000
#
#           lw
# 0  -3.535000
# 1  -1.714994
# 2 -49.000000

# %%
sns.boxplot(y = df["Annual_Income_k$"])
plt.title("Outliers in Annual Income")
plt.show()

# %%
# Demographic Profiling : customers Age and Gender Distribution

# %%
# Age Distribution
plt.subplot(1, 2, 1)
sns.histplot(df["Age"].dropna(), bins=30, kde=True, color="skyblue")
plt.title("Age Distribution")
# Out:
# Text(0.5, 1.0, 'Age Distribution')

# %%
# Gender Count
plt.subplot(1, 2, 2)
sns.countplot(data=df, x="Gender", palette="Set2")
plt.title("Gender Distribution")
# Out:
# C:\Users\ashwini\AppData\Local\Temp\ipykernel_22544\232787044.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x="Gender", palette="Set2")
# Text(0.5, 1.0, 'Gender Distribution')

# %%
# Financial Behavior : to check Income vs Spending Scores

# %%
plt.figure(figsize = (10, 6))
sns.scatterplot(data = df, x = "Annual_Income_k$", y = "Spending_Score", hue = "Gender", alpha=0.5)
plt.title("Income vs Spending Score")
# Out:
# Text(0.5, 1.0, 'Income vs Spending Score')
